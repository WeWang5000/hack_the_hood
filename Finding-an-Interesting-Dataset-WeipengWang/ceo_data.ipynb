# %%
import pandas

ceo_data = pandas.read_csv("ceo_data.csv")

ceo_data
# Out:
#     ranking                   ceo  \
# 0         1        Pichai, Sundar
# 1         2     Ianniello, Joseph
# 2         3          Testrow, Ian
# 3         4          Swan, Robert
# 4         5              Su, Lisa
# 5         6          Wenig, Devin
# 6         7          Dolan, James
# 7         8           Plant, John
# 8         9       Ermotti, Sergio
# 9        10          Iger, Robert
# 10       11  Silbermann, Benjamin
# 11       12         Zaslav, David
# 12       13       Maffei, Gregory
# 13       14      Patricio, Miguel
# 14       15        Nadella, Satya
# 15       16    Gelsinger, Patrick
# 16       17    Khosrowshahi, Dara
# 17       18      Schneider, David
# 18       19         Ritter, Rubin
# 19       20         Gentz, Robert
# 20       21    McDermott, William
# 21       22     Narayen, Shantanu
# 22       23      Hastings, Wilmot
# 23       24          Merlo, Larry
# 24       25          Simon, Irwin
# 25       26        Roberts, Brian
# ...
